# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

base_dir = "/content/drive/MyDrive/Dataset Protein"

cb513 = np.load(base_dir + "/cb513+profile_split1.npy.gz", allow_pickle=True)
cullpdb = np.load(base_dir + "/cullpdb+profile_5926_filtered.npy.gz", allow_pickle=True)

# reshape
cb513 = cb513.reshape(cb513.shape[0], 700, 57)
cullpdb = cullpdb.reshape(cullpdb.shape[0], 700, 57)

print(cb513.shape)
print(cullpdb.shape)
# Out:
# /tmp/ipykernel_736/119562786.py:5: UserWarning: Reading `.npy` or `.npz` file required additional header parsing as it was created on Python 2. Save the file again to speed up loading and avoid this warning.
#   cb513 = np.load(base_dir + "/cb513+profile_split1.npy.gz", allow_pickle=True)
# (514, 700, 57)
# (5365, 700, 57)

# %%
#Split data
np.random.seed(42)

n_samples = cullpdb.shape[0]
indices = np.random.permutation(n_samples)

split = int(0.8 * n_samples)

train_idx = indices[:split]
val_idx   = indices[split:]

dataset_train = cullpdb[train_idx]
dataset_val   = cullpdb[val_idx]
dataset_test  = cb513

# %%
def extract(dataset):
    y = dataset[:, :, 21:24] #Q3

    #fitur
    X_aa = dataset[:, :, :21]
    X_other = dataset[:, :, 24:]
    X = np.concatenate([X_aa, X_other], axis=2)

    #mask
    mask = np.sum(X, axis=2) != 0

    return X.astype(np.float32), y.astype(np.float32), mask

#Apply dataset
X_train, y_train, mask_train = extract(dataset_train)
X_val,   y_val,   mask_val   = extract(dataset_val)
X_test,  y_test,  mask_test  = extract(dataset_test)

X_train = X_train[..., np.newaxis]
X_val   = X_val[..., np.newaxis]
X_test  = X_test[..., np.newaxis]

# %% [markdown]
# # Optuna Modelng

# %%
# !pip install optuna
import optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 17.4 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.8.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dropout, Reshape, TimeDistributed, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
def objective(trial):

    # Hyperparameter
    filters = trial.suggest_categorical("filters", [32, 64, 128])
    kernel_size = trial.suggest_int("kernel_size", 3, 7)
    dropout_rate = trial.suggest_float("dropout", 0.2, 0.5)
    lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)

    # Model CNN 2D
    input_layer = Input(shape=(700, 54, 1))

    x = Conv2D(filters, (kernel_size, kernel_size), padding='same', activation='relu')(input_layer)
    x = Conv2D(filters * 2, (kernel_size, kernel_size), padding='same', activation='relu')(x)

    x = Dropout(dropout_rate)(x)

    # Reshape sekuens
    x = Reshape((700, 54 * (filters * 2)))(x)

    x = TimeDistributed(Dense(64, activation='relu'))(x)
    output = TimeDistributed(Dense(3, activation='softmax'))(x)

    model = Model(inputs=input_layer, outputs=output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # Train
    history = model.fit(
        X_train, y_train,
        sample_weight=mask_train.astype(float),
        validation_data=(X_val, y_val, mask_val.astype(float)),
        epochs=3,
        batch_size=16,
        verbose=0
    )

    # Best val accuracy
    val_acc = max(history.history['val_accuracy'])

    tf.keras.backend.clear_session()

    return val_acc

# %%
study = optuna.create_study(direction="maximize")

study.optimize(objective, n_trials=10)

print("Best Params:", study.best_params)
print("Best Accuracy:", study.best_value)
# Out:
# [I 2026-04-24 06:12:11,035] A new study created in memory with name: no-name-ae3bea0f-f0c8-4eea-a16f-891d0b124172
# [I 2026-04-24 06:40:35,256] Trial 0 finished with value: 0.750762939453125 and parameters: {'filters': 128, 'kernel_size': 7, 'dropout': 0.2002971008320208, 'lr': 0.0009680447801398719}. Best is trial 0 with value: 0.750762939453125.
# [I 2026-04-24 07:08:08,984] Trial 1 finished with value: 0.7507947087287903 and parameters: {'filters': 128, 'kernel_size': 7, 'dropout': 0.40430789239254455, 'lr': 0.003002819042369405}. Best is trial 1 with value: 0.7507947087287903.
# [I 2026-04-24 07:28:00,621] Trial 2 finished with value: 0.7506776452064514 and parameters: {'filters': 64, 'kernel_size': 4, 'dropout': 0.4676490832305566, 'lr': 0.0011664136004632683}. Best is trial 1 with value: 0.7507947087287903.
# [I 2026-04-24 07:44:41,106] Trial 3 finished with value: 0.7506416440010071 and parameters: {'filters': 32, 'kernel_size': 7, 'dropout': 0.4942095405219658, 'lr': 0.002194025099632155}. Best is trial 1 with value: 0.7507947087287903.
# [I 2026-04-24 08:13:33,984] Trial 4 finished with value: 0.7506910562515259 and parameters: {'filters': 128, 'kernel_size': 7, 'dropout': 0.31730477785925015, 'lr': 0.0002975084197606765}. Best is trial 1 with value: 0.7507947087287903.
# [I 2026-04-24 08:42:13,996] Trial 5 finished with value: 0.7507054209709167 and parameters: {'filters': 128, 'kernel_size': 4, 'dropout': 0.2657135091896698, 'lr': 0.004370365046526511}. Best is trial 1 with value: 0.7507947087287903.
# [I 2026-04-24 08:58:34,141] Trial 6 finished with value: 0.750650942325592 and parameters: {'filters': 32, 'kernel_size': 6, 'dropout': 0.405323193176626, 'lr': 0.00010655245117318949}. Best is trial 1 with value: 0.7507947087287903.
# [I 2026-04-24 09:27:23,917] Trial 7 finished with value: 0.7506921887397766 and parameters: {'filters': 128, 'kernel_size': 6, 'dropout': 0.2600105559422608, 'lr': 0.0002824394333367244}. Best is trial 1 with value: 0.7507947087287903.
# [I 2026-04-24 09:56:09,667] Trial 8 finished with value: 0.750729501247406 and parameters: {'filters': 128, 'kernel_size': 7, 'dropout': 0.3815841881287507, 'lr': 0.00035958850968131976}. Best is trial 1 with value: 0.7507947087287903.
# [I 2026-04-24 10:17:10,621] Trial 9 finished with value: 0.7506536245346069 and parameters: {'filters': 64, 'kernel_size': 4, 'dropout': 0.34004466513794296, 'lr': 0.00047724165681752056}. Best is trial 1 with value: 0.7507947087287903.
# Best Params: {'filters': 128, 'kernel_size': 7, 'dropout': 0.40430789239254455, 'lr': 0.003002819042369405}
# Best Accuracy: 0.7507947087287903

# %%
# Hasil dari Optuna — isi manual setelah mendapatkan best params,
# agar tidak mengulang proses Optuna dari awal
best = {
    'filters'     : 128,
    'kernel_size' : 7,
    'dropout'     : 0.40430789239254455,
    'lr'          : 0.003002819042369405
}

# %%
# variable best parameter jika saat menggunakan Optuna pertama kali, CTRL + /. kalau tidak lanjut aja
# best = study.best_params

input_layer = Input(shape=(700, 54, 1))

x = Conv2D(best['filters'], (best['kernel_size'], best['kernel_size']), padding='same', activation='relu')(input_layer)
x = Conv2D(best['filters'] * 2, (best['kernel_size'], best['kernel_size']), padding='same', activation='relu')(x)

x = Dropout(best['dropout'])(x)

# Reshape kembali ke format sekuens
x = Reshape((700, 54 * (best['filters'] * 2)))(x)

x = TimeDistributed(Dense(64, activation='relu'))(x)
output = TimeDistributed(Dense(3, activation='softmax'))(x)

model = Model(inputs=input_layer, outputs=output)

optimizer = tf.keras.optimizers.Adam(learning_rate=best['lr'])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 700, 54, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 700, 54, 128)   │         6,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 700, 54, 256)   │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 700, 54, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 700, 13824)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 700, 64)        │       884,800 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 700, 3)         │           195 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,497,283 (9.53 MB)
#  Trainable params: 2,497,283 (9.53 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    sample_weight=mask_train.astype(float),
    validation_data=(X_val, y_val, mask_val.astype(float)),
    epochs=20,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 1181s 3s/step - accuracy: 0.7504 - loss: 0.0157 - val_accuracy: 0.7506 - val_loss: 0.0111
# Epoch 2/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 374s 1s/step - accuracy: 0.7518 - loss: 0.0102 - val_accuracy: 0.7507 - val_loss: 0.0100
# Epoch 3/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 374s 1s/step - accuracy: 0.7519 - loss: 0.0097 - val_accuracy: 0.7508 - val_loss: 0.0102
# Epoch 4/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 374s 1s/step - accuracy: 0.7519 - loss: 0.0093 - val_accuracy: 0.7508 - val_loss: 0.0096
# Epoch 5/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 374s 1s/step - accuracy: 0.7520 - loss: 0.0087 - val_accuracy: 0.7509 - val_loss: 0.0094
# Epoch 6/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 374s 1s/step - accuracy: 0.7522 - loss: 0.0081 - val_accuracy: 0.7509 - val_loss: 0.0098
# Epoch 7/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 374s 1s/step - accuracy: 0.7523 - loss: 0.0074 - val_accuracy: 0.7509 - val_loss: 0.0096
# Epoch 8/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 374s 1s/step - accuracy: 0.7526 - loss: 0.0066 - val_accuracy: 0.7508 - val_loss: 0.0102

# %%
# Test dengan CB513
test_loss, test_acc = model.evaluate(
    X_test, y_test,
    sample_weight=mask_test.astype(float)
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 127s 4s/step - accuracy: 0.8141 - loss: 0.0114

# %%
import matplotlib.pyplot as plt

# Best epoch
best_val_loss_epoch = np.argmin(history.history['val_loss'])
best_val_acc_epoch  = np.argmax(history.history['val_accuracy'])

plt.figure(figsize=(14, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')

plt.axvline(best_val_acc_epoch, linestyle='--',
            label=f'Best Val Acc (Epoch {best_val_acc_epoch+1})')

min_acc = min(history.history['val_accuracy'])
max_acc = max(history.history['accuracy'])

plt.yticks(np.arange(round(min_acc, 2), round(max_acc, 2)+0.05, 0.01))

plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')

plt.axvline(best_val_loss_epoch, linestyle='--',
            label=f'Best Val Loss (Epoch {best_val_loss_epoch+1})')

min_loss = min(history.history['val_loss'])
max_loss = max(history.history['loss'])

plt.yticks(np.arange(round(min_loss, 2), round(max_loss, 2)+0.05, 0.01))

plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score, roc_auc_score

# Predict
y_pred = model.predict(X_test)

# Flatten + mask
mask = mask_test.flatten()

y_true = y_test.reshape(-1, 3)[mask]
y_pred = y_pred.reshape(-1, 3)[mask]

# Convert ke label
y_true_label = y_true.argmax(axis=1)
y_pred_label = y_pred.argmax(axis=1)

# Metrics
precision = precision_score(y_true_label, y_pred_label, average='macro')
recall    = recall_score(y_true_label, y_pred_label, average='macro')
f1        = f1_score(y_true_label, y_pred_label, average='macro')

# AUC
auc = roc_auc_score(y_true, y_pred, multi_class='ovr')

print("===== FINAL METRICS =====")
print(f"Accuracy : {test_acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
print(f"AUC      : {auc:.4f}")
print(f"Loss     : {test_loss:.4f}")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 147s 4s/step
# ===== FINAL METRICS =====
# Accuracy : 0.8141
# Precision: 0.4240
# Recall   : 0.6292
# F1 Score : 0.4385
# AUC      : 0.9493
# Loss     : 0.0114
